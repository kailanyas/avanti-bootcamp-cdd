# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.to_csv("../data/raw/data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.to_csv("../data/raw/data.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel": "survived",
        "descricao": "Indica se o passageiro sobreviveu ou não",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "pclass",
        "descricao": "Classe em que o passageiro viajou (1, 2 ou 3)",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel": "sex",
        "descricao": "Gênero do passageiro",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "age",
        "descricao": "Idade do passageiro",
        "tipo":"quantitativa",
        "subtipo":"contínua"
    },{
        "variavel": "sibsp",
        "descricao": "Número de irmãos ou cônjuge a bordo",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "parch",
        "descricao": "Número de pais ou filhos a bordo",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "fare",
        "descricao": "Valor da tarifa paga pelo passageiro",
        "tipo":"quantitativa",
        "subtipo":"contínua"
    },{
        "variavel": "embarked",
        "descricao": "Porto em que o passageiro embarcou",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "class",
        "descricao": "Classe do passageiro (em ordinal)",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel": "who",
        "descricao": "Categoria do passageiro",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "adult_male",
        "descricao": "Indica se o passageiro é um homem adulto",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "deck",
        "descricao": "Convés do passageiro",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "embark_town",
        "descricao": "Cidade em que o passageiro embarcou",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "alive",
        "descricao": "Indica se o passageiro sobreviveu",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "alone",
        "descricao": "Indica se o passageiro estava sozinho",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    }
])
dicionario.to_csv("../data/external/dictionary.csv", index=False)
dicionario
# Out:
#        variavel                                      descricao          tipo  \
# 0      survived       Indica se o passageiro sobreviveu ou não   qualitativa
# 1        pclass  Classe em que o passageiro viajou (1, 2 ou 3)   qualitativa
# 2           sex                           Gênero do passageiro   qualitativa
# 3           age                            Idade do passageiro  quantitativa
# 4         sibsp            Número de irmãos ou cônjuge a bordo  quantitativa
# 5         parch               Número de pais ou filhos a bordo  quantitativa
# 6          fare           Valor da tarifa paga pelo passageiro  quantitativa
# 7      embarked             Porto em que o passageiro embarcou   qualitativa
# 8         class              Classe do passageiro (em ordinal)   qualitativa
# 9           who                        Categoria do passageiro   qualitativa
# 10   adult_male       Indica se o passageiro é um homem adulto   qualitativa
# ...
